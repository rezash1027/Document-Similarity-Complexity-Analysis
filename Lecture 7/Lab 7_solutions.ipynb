# %% [markdown]
# # Unit 7 lab: Map/Reduce
#
#
#
# The following code loads in the text of H.G.Wells' novel "Time Machine" and turns the novel into a list of lines and each line into a list of tokens.  We will think of and refer to each line as a *document*.  Run the code and print out the first five lines.

# %%
from nltk.tokenize import word_tokenize

document1="timemachine.txt"

lines=[]
with open(document1) as instream:
    for line in instream:        
        tokens=[token.lower() for token in word_tokenize(line.rstrip())]  #strip excess white space, tokenize, lower-case
        lines.append(tokens)

# %%
print(lines[:5])
# Out:
# [['\ufeffproject', 'gutenberg', "'s", 'the', 'time', 'machine', ',', 'by', 'h.', 'g.', '(', 'herbert', 'george', ')', 'wells'], [], ['this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with'], ['almost', 'no', 'restrictions', 'whatsoever', '.', 'you', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or'], ['re-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'project', 'gutenberg', 'license', 'included']]

# %% [markdown]
# ### Exercise 1
# Write a simple function (i.e., without using map/reduce) to count the number of times each word occurs and store it in a dictionary.  Use it to find out how many times the word 'time' occurs in the novel.

# %%
def countline(aline,adict):
    for token in aline:
        adict[token]=adict.get(token,0)+1
    

def countdoc(doclines):
    countdict={}
    for line in doclines:
        countline(line,countdict)
        
    return countdict

mydict=countdoc(lines)
print(mydict.get("time",0))
# Out:
# 201

# %%
#alternative
from collections import Counter
def word_count(documents):
    return Counter(word for document in documents for word in document)

counts=word_count(lines)
counts["time"]
# Out:
# 201

# %% [markdown]
# Now lets see how we can rewrite this in the Map/Reduce paradigm.  Below is a map_reduce function which takes a list of inputs, a mapper function and a reducer function

# %%
from collections import defaultdict

def map_reduce(inputs,mapper,reducer):
    
    collector=defaultdict(list)  #this dictionary is where we will store intermediate results
                                 #it will map keys to lists of values (default value of a list is [])
                                 #in a real system, this would be stored in individual files at the map nodes
                                 #and then transferred to the reduce nodes
    
    #map stage
    for inp in inputs:
        for key, value in mapper(inp):     #pass each input to the mapper function and receive back each key,value pair yielded
            collector[key].append(value)     #append the value to the list for that key in the intermediate store
            
    #reduce stage 
    outputs=[]
    for key,values in collector.items():  #take each pair of key, value-lists and pass it to the reduce function
        for res in reducer(key,values):       #take each pair yielded by the reducer and add it to the outputs list
            outputs.append(res)
    
    return outputs

# %% [markdown]
# Now we define a mapper function and a reducer function particular to our word-counting task

# %%
def wc_mapper(document):
    for word in document:
        yield(word,1)
        
def wc_reducer(word,counts):
    yield(word,sum(counts))

# %% [markdown]
# Lets run this and display the results.

# %%
#display() just prints the dictionary items using tab separation
#ipl is the desired number of columns per line
def display(results,ipl=6):
    line=""
    itemcount=1
    for res in results:
        if itemcount<ipl:
            for thing in res:
                line+=str(thing)+"\t"
                itemcount+=1
        else:
            print(line)
            itemcount=1
            line=""

results = map_reduce(lines,wc_mapper,wc_reducer)
display(results)
# Out:
# ﻿project	1	gutenberg	30	's	77
# time	201	machine	91	,	2372
# h.	4	g.	4	(	32
# george	3	)	32	wells	12
# ebook	9	is	131	for	243
# of	1268	anyone	5	anywhere	3
# no	99	cost	3	and	1303
# almost	25	restrictions	2	whatsoever	2
# you	196	may	48	copy	12
# give	8	away	39	or	162
# under	38	terms	23	project	86
# included	3	online	4	www.gutenberg.net	3
# :	59	author	1	release	1
# october	2	2	2	2004	1
# #	1	35	1	]	4
# updated	2	3	6	2014	1
# english	3	***	6	start	6
# i	1266	traveller	61	so	106
# be	112	convenient	5	to	760
# him	39	was	551	expounding	2
# recondite	1	matter	6	us	36
# grey	10	eyes	35	shone	8
# usually	3	pale	9	face	38
# animated	3	fire	29	burned	6
# soft	15	radiance	1	incandescent	1
# in	594	lilies	1	silver	6
# bubbles	1	that	447	flashed	4
# our	59	glasses	1	chairs	2
# patents	1	embraced	1	caressed	2
# than	36	submitted	1	sat	22
# there	122	luxurious	1	after-dinner	1
# when	55	thought	57	roams	1
# free	9	trammels	1	precision	1
# put	34	way	40	--	180
# points	3	lean	2	forefinger	2
# we	90	lazily	1	admired	1
# over	52	new	30	paradox	5
# 'you	11	must	59	follow	9
# carefully	6	shall	9	have	125
# one	117	two	28	ideas	3
# universally	1	accepted	7	geometry	4
# they	123	taught	2	school	1
# on	148	misconception	1	'	248
# not	155	large	14	thing	66
# begin	4	?	96	said	89
# an	88	argumentative	1	person	6
# hair	6	do	51	mean	7
# accept	2	anything	7	without	22
# ground	17	soon	21	admit	4
# need	8	from	136	know	29
# mathematical	3	line	11	thickness	5
# has	22	real	9	existence	5
# plane	1	these	76	things	36
# abstractions	1	'that	10	all	135
# psychologist	25	'nor	1	having	4
# length	8	breadth	3	can	49
# 'there	6	object	5	'of	3
# body	6	exist	2	'so	7
# people	49	think	36	but	190
# moment	31	_instantaneous_	1	'do	4
# 'can	1	does	5	any	76
# pensive	1	'clearly	2	proceeded	4
# extension	1	_four_	1	directions	2
# through	50	natural	7	infirmity	1
# which	92	explain	9	incline	2
# fact	8	really	9	four	11
# three	19	call	4	planes	2
# fourth	6	however	16	tendency	5
# unreal	3	distinction	1	between	15
# latter	3	because	11	happens	1
# moves	2	intermittently	1	direction	6
# beginning	6	end	26	lives	2
# young	8	man	67	making	5
# efforts	6	relight	1	cigar	4
# ;	113	...	10	clear	13
# 'now	6	remarkable	2	extensively	1
# continued	2	slight	5	accession	1
# 'really	2	what	71	meant	3
# though	18	some	94	who	29
# about	77	another	37	looking	19
# difference	5	except	10	it_	1
# got	25	hold	6	wrong	10
# idea	10	heard	20	say	20
# provincial	4	mayor	4	'it	19
# mathematicians	1	spoken	2	always	10
# reference	2	each	16	angles	2
# philosophical	1	been	75	asking	1
# _three_	1	particularly	5	other	50
# tried	22	construct	1	four-dimension	1
# simon	1	newcomb	1	york	1
# month	2	ago	8	how	45
# surface	8	represent	2	figure	11
# similarly	1	models	1	could	94
# master	1	perspective	1	see	48
# knitting	1	brows	1	lapsed	1
# introspective	1	state	11	lips	5
# repeats	1	mystic	1	words	6
# now	72	after	33	brightening	1
# transitory	2	manner	4	'well	6
# telling	8	work	55	my	437
# curious	4	here	42	portrait	1
# years	18	old	28	fifteen	2
# twenty-three	1	evidently	6	sections	2
# representations	2	four-dimensioned	1	fixed	1
# 'scientific	1	pause	5	required	2
# assimilation	1	'know	1	well	27
# popular	1	scientific	2	diagram	1
# record	1	trace	7	finger	3
# movement	4	barometer	1	yesterday	2
# night	36	fell	16	then	127
# rose	13	again	61	gently	5
# surely	1	mercury	2	did	42
# recognized	5	certainly	5	traced	1
# therefore	2	conclude	1	time-dimension	3
# medical	24	staring	3	hard	7
# 'if	2	regarded	2	something	16
# move	13	smiled	5	'are	3
# freely	7	left	26	go	18
# forward	8	enough	28	men	14
# up	74	down	86	gravitation	2
# 'not	2	exactly	10	balloons	2
# save	11	jumping	1	inequalities	1
# freedom	4	vertical	2	'still	2
# 'easier	1	far	20	easier	1
# get	21	present	7	'my	3
# sir	2	just	16	where	30
# world	35	gone	20	getting	6
# existences	1	immaterial	1	passing	4
# velocity	5	cradle	1	grave	2
# travel	7	_down_	1	began	40
# miles	4	above	23	earth	21
# difficulty	4	interrupted	1	_can_	1
# discovery	3	am	12	recalling	1
# vividly	3	back	40	instant	2
# occurrence	1	become	7	absent-minded	1
# means	9	staying	2	more	60
# animal	10	six	1	feet	18
# better	10	off	28	respect	1
# balloon	1	hope	7	ultimately	2
# stop	7	accelerate	1	drift	3
# 'oh	1	_this_	1	'why	2
# 'what	7	show	4	black	30
# argument	1	never	20	convince	1
# investigations	1	long	33	vague	6
# 'to	4	!	67	exclaimed	1
# driver	1	determines	1	contented	2
# laughter	4	experimental	1	verification	3
# remarkably	1	historian	1	suggested	6
# might	35	verify	2	account	7
# hastings	1	attract	1	attention	7
# ancestors	2	tolerance	1	anachronisms	1
# homer	1	plato	1	'in	4
# plough	1	little-go	1	german	1
# improved	1	'then	7	future	24
# invest	1	money	4	leave	7
# interest	9	hurry	1	ahead	2
# 'erected	1	strictly	1	communistic	1
# wild	5	extravagant	1	theories	3
# talked	2	until	20	'experimental	1
# going	15	_that_	1	'the	20
# brain-weary	1	'let	1	your	17
# 'though	1	humbug	1	round	36
# smiling	4	faintly	2	hands	28
# trousers	1	pockets	3	walked	10
# out	74	room	14	slippers	1
# passage	4	laboratory	19	looked	34
# 'some	1	sleight-of-hand	1	trick	6
# conjurer	1	seen	22	burslem	1
# preface	1	came	105	anecdote	1
# held	7	hand	48	glittering	2
# framework	2	scarcely	4	larger	10
# clock	2	delicately	1	made	36
# transparent	2	crystalline	2	substance	4
# follows	1	unless	7	explanation	7
# unaccountable	1	took	32	octagonal	1
# scattered	4	set	21	front	6
# hearthrug	1	table	15	placed	3
# drew	6	chair	4	shaded	1
# light	42	model	8	also	6
# dozen	2	candles	3	brass	5
# mantel	3	several	12	sconces	1
# illuminated	3	low	5	arm-chair	1
# fireplace	1	behind	16	shoulder	9
# profile	1	stood	24	alert	1
# incredible	6	subtly	1	conceived	1
# played	2	conditions	11	'this	3
# resting	1	elbows	1	pressing	1
# apparatus	3	plan	2	notice	5
# singularly	4	askew	2	odd	14
# appearance	3	bar	9	pointed	6
# 'also	1	lever	17	peered	1
# make	23	retorted	1	imitated	1
# want	7	clearly	11	understand	14
# sends	1	gliding	1	reverses	1
# saddle	7	represents	1	seat	4
# press	1	vanish	3	pass	5
# good	12	look	18	too	44
# yourselves	1	trickery	2	waste	5
# 'm	10	quack	1	minute	22
# forth	14	towards	47	'no	3
# 'lend	1	turning	4	individual	5
# sent	2	interminable	2	voyage	2
# certain	20	breath	5	wind	6
# jumped	2	blown	4	swung	2
# ghost	5	second	13	eddy	1
# bare	6	everyone	1	silent	13
# recovered	3	stupor	1	laughed	9
# reminiscence	2	went	49	tobacco	2
# fill	1	pipe	5	stared	9
# earnest	1	seriously	3	believe	10
# 'certainly	2	stooping	2	spill	1
# lighting	2	unhinged	1	helped	2
# big	17	nearly	9	indicated	2
# 'into	1	past	14	interval	5
# 'because	1	presume	1	moved	9
# visible	4	first	49	thursday	5
# objections	2	remarked	4	air	20
# bit	3	presentation	2	below	12
# diluted	1	reassured	2	simple	5
# psychology	1	plain	9	helps	1
# nor	8	appreciate	3	spoke	7
# spinning	2	bullet	1	flying	1
# times	13	hundred	13	faster	8
# while	19	impression	6	creates	1
# one-hundredth	1	laughing	7	vacant	1
# sounds	7	plausible	4	to-night	3
# common	5	sense	11	'would	1
# itself	8	therewith	3	taking	3
# draughty	1	corridor	5	remember	12
# queer	11	broad	4	head	23
# dance	5	shadows	7	followed	16
# incredulous	3	beheld	2	edition	2
# nickel	2	filed	2	sawn	1
# crystal	1	complete	5	twisted	1
# lay	16	unfinished	1	bench	4
# sheets	4	drawings	2	quartz	3
# serious	3	showed	6	christmas	1
# holding	5	aloft	1	intend	1
# life	17	none	9	knew	15
# eye	8	winked	1	solemnly	3
# believed	2	those	19	clever	2
# suspected	3	subtle	3	reserve	1
# ambush	1	lucid	1	frankness	1
# explained	2	_him_	1	less	16
# perceived	5	motives	1	pork	1
# touch	4	whim	1	among	33
# distrusted	1	frame	4	tricks	1
# easily	4	deportment	1	somehow	7
# trusting	1	their	91	reputations	1
# furnishing	1	nursery	1	egg-shell	1
# next	14	potentialities	1	ran	17
# minds	1	plausibility	1	practical	1
# possibilities	2	anachronism	1	utter	2
# preoccupied	1	discussing	1	whom	4
# friday	3	linnaean	1	similar	2
# laid	2	considerable	5	stress	1
# candle	2	richmond	1	suppose	13
# guests	3	arriving	1	late	6
# five	3	already	19	assembled	1
# standing	9	sheet	1	paper	7
# half-past	2	seven	6	'd	2
# 'where	4	naming	2	host	2
# come	31	unavoidably	1	detained	1
# note	2	lead	2	says	1
# comes	7	seems	2	pity	2
# spoil	1	editor	20	well-known	1
# thereupon	1	doctor	3	rang	3
# besides	4	myself	51	attended	1
# blank	3	aforementioned	1	journalist	9
# shy	2	beard	1	observation	1
# mouth	6	evening	11	speculation	2
# absence	4	half-jocular	1	spirit	5
# volunteered	1	wooden	1	'ingenious	1
# day	31	week	4	midst	1
# door	17	noise	3	facing	4
# 'at	5	wider	2	gave	12
# surprise	5	'good	1	heavens	2
# amazing	2	plight	1	coat	4
# dirty	1	smeared	2	green	24
# disordered	2	greyer	1	either	11
# dirt	1	colour	7	actually	1
# ghastly	2	chin	3	brown	9
# half	11	healed	1	expression	3
# drawn	3	intense	7	suffering	3
# doorway	5	dazzled	3	limp	1
# tramps	1	silence	2	expecting	2
# painfully	2	wine	2	filled	2
# champagne	2	pushed	7	drained	1
# flickered	3	across	22	seem	7
# disturb	1	faltering	1	articulation	1
# draught	1	grew	26	brighter	5
# cheeks	1	glance	3	faces	8
# approval	1	warm	6	comfortable	2
# wash	1	dress	1	mutton	2
# meat	8	rare	7	visitor	1
# question	9	'tell	2	funny	1
# lameness	2	padding	1	sound	12
# place	23	nothing	13	them	86
# tattered	3	blood-stained	1	socks	1
# till	5	remembered	4	detested	1
# wool-gathering	1	'remarkable	1	behaviour	2
# scientist	1	thinking	8	wont	1
# brought	4	game	1	'has	2
# amateur	1	cadger	1	read	6
# limping	2	upstairs	1	else	3
# recover	4	completely	2	hated	1
# waiting	6	hot	4	plate	2
# fork	2	grunt	1	suit	2
# conversation	3	exclamatory	1	gaps	1
# fervent	1	curiosity	4	'does	1
# eke	1	modest	2	income	1
# nebuchadnezzar	1	phases	1	inquired	1
# assured	8	business	6	meeting	2
# raised	3	_was_	2	cover	1
# home	6	resorted	1	caricature	1
# price	1	joined	1	easy	4
# ridicule	1	both	7	joyous	1
# special	2	correspondent	1	reports	2
# shouting	1	dressed	2	ordinary	1
# remained	5	change	9	startled	5
# 'these	1	chaps	1	middle	1
# lot	2	reserved	1	quietly	3
# stick	2	'story	2	eat	3
# peptone	1	arteries	1	thanks	1
# 'have	1	full	26	nodding	1
# verbatim	1	fingernail	1	started	6
# poured	1	rest	9	uncomfortable	3
# questions	2	kept	7	rising	7
# same	38	relieve	1	tension	1
# hettie	1	potter	1	devoted	3
# appetite	3	tramp	1	smoked	1
# eyelashes	1	clumsy	3	usual	2
# regularity	1	determination	1	sheer	2
# apologize	1	reached	6	smoking-room	4
# greasy	1	plates	3	ringing	1
# dash	1	chose	1	leaning	1
# ca	3	argue	2	happened	12
# interruptions	2	badly	2	lying	4
# every	13	o'clock	3	lived	6
# human	21	ever	14	worn	4
# sleep	10	bed	2	agreed	2
# echoed	1	weary	3	afterwards	4
# keenness	1	inadequacy	3	pen	1
# express	3	quality	2	attentively	1
# sincere	1	circle	3	intonation	1
# turns	1	hearers	1	shadow	7
# knees	3	downward	3	glanced	1
# iii	1	principles	1	actual	4
# workshop	3	travel-worn	1	truly	2
# rail	4	bent	3	expected	3
# putting	4	inch	1	short	7
# ten	5	to-day	4	machines	4
# tap	2	screws	1	drop	1
# rod	1	suicide	2	holds	1
# skull	4	feels	1	starting	3
# immediately	2	reel	1	nightmare	2
# falling	5	intellect	2	tricked	1
# teeth	4	gripped	3	thud	6
# dark	27	mrs.	1	watchett	2
# seeing	2	garden	6	her	74
# she	43	shoot	1	rocket	2
# position	4	fainter	3	eddying	4
# ears	7	strange	32	dumb	1
# descended	1	afraid	6	convey	6
# sensations	5	excessively	3	unpleasant	6
# helpless	5	headlong	4	horrible	8
# imminent	3	smash	1	pace	4
# wing	1	dim	13	suggestion	5
# sun	30	hopping	3	swiftly	8
# leaping	3	supposed	2	destroyed	2
# scaffolding	1	fast	7	conscious	1
# snail	1	crawled	1	dashed	3
# darkness	27	painful	4	intermittent	1
# moon	18	quarters	1	glimpse	4
# stars	11	gaining	1	palpitation	1
# continuous	1	greyness	2	wonderful	3
# blue	9	splendid	7	luminous	3
# early	4	twilight	6	jerking	1
# brilliant	2	arch	2	fluctuating	2
# landscape	3	misty	1	hill-side	6
# stands	2	trees	10	growing	11
# puffs	1	vapour	3	spread	5
# huge	13	buildings	9	rise	4
# dreams	2	melting	1	flowing	1
# registered	3	speed	2	raced	2
# swayed	3	solstice	2	consequently	1
# snow	2	brief	2	spring	1
# hysterical	1	exhilaration	1	swaying	3
# confused	2	attend	1	madness	2
# futurity	3	scarce	4	fresh	3
# impressions	2	dread	4	possession	5
# humanity	10	advances	1	rudimentary	2
# appear	3	elusive	1	fluctuated	1
# massive	1	yet	31	built	4
# mist	2	richer	2	flow	2
# wintry	1	intermission	1	veil	1
# possibility	4	finding	3	occupied	3
# attenuated	1	slipping	2	interstices	1
# substances	1	involved	1	jamming	1
# whatever	2	bringing	1	atoms	1
# contact	6	obstacle	1	profound	4
# reaction	2	possibly	10	far-reaching	1
# result	2	blow	4	possible	6
# occurred	5	unavoidable	1	risks	1
# longer	7	cheerful	1	insensibly	1
# strangeness	1	everything	8	sickly	1
# prolonged	2	upset	1	nerve	1
# petulance	1	resolved	5	forthwith	2
# fool	2	lugged	1	incontinently	5
# clap	1	thunder	2	stunned	1
# hail	5	hissing	2	sitting	3
# overset	1	lawn	10	surrounded	3
# bushes	14	mauve	1	purple	4
# dropping	1	shower	1	beating	3
# rebounding	1	dancing	4	hung	9
# drove	8	smoke	6	wet	3
# ``	30	fine	1	hospitality	1
# innumerable	4	'presently	1	colossal	4
# stone	9	loomed	1	indistinctly	1
# rhododendrons	2	downpour	2	invisible	1
# columns	2	thinner	2	distinctly	3
# touched	7	marble	3	shape	5
# sphinx	22	wings	2	instead	8
# vertically	1	sides	4	hover	1
# appeared	11	bronze	19	thick	11
# chanced	3	sightless	1	greatly	4
# imparted	1	disease	3	hour	5
# recede	1	denser	1	tore	1
# threadbare	1	lightening	1	promise	2
# temerity	1	altogether	11	withdrawn	1
# grown	2	passion	4	race	8
# manliness	1	developed	1	inhuman	5
# overwhelmingly	1	powerful	1	old-world	1
# disgusting	1	likeness	1	foul	4
# slain	1	'already	1	vast	12
# intricate	1	parapets	1	tall	4
# dimly	3	creeping	10	lessening	1
# seized	3	panic	1	fear	24
# strove	1	readjust	2	shafts	3
# thunderstorm	3	swept	3	aside	2
# garments	3	summer	1	shreds	1
# nothingness	1	distinct	5	shining	4
# unmelted	1	hailstones	1	piled	1
# naked	1	bird	1	knowing	1
# swoop	1	frenzy	4	breathing	7
# fiercely	1	wrist	1	knee	1
# onset	1	struck	16	violently	7
# heavily	1	attitude	2	mount	2
# prompt	1	retreat	3	courage	3
# fearfully	1	remote	8	circular	3
# wall	5	nearer	6	group	3
# clad	4	rich	5	robes	3
# voices	5	approaching	3	coming	14
# shoulders	2	running	15	emerged	4
# leading	2	straight	6	tunic	1
# waist	1	leather	1	sandals	2
# distinguish	2	noticing	1	'he	1
# graceful	3	indescribably	3	frail	4
# consumptive	1	hectic	1	beauty	5
# sight	6	regained	1	confidence	6
# fragile	2	bearing	2	sign	2
# following	6	sweet	4	liquid	1
# exquisite	3	creatures	15	addressed	1
# harsh	4	shook	3	pointing	2
# tentacles	2	alarming	1	pretty	8
# gentleness	1	childlike	1	ease	5
# flinging	5	nine-pins	1	warn	2
# happily	1	danger	6	hitherto	6
# reaching	2	unscrewed	1	levers	7
# communication	1	features	4	further	12
# dresden-china	1	type	3	prettiness	2
# curly	1	sharp	3	neck	7
# faintest	2	mouths	1	thin	3
# mild	1	egotism	1	fancied	9
# 'as	9	effort	6	communicate	1
# cooing	2	notes	1	hesitating	2
# chequered	1	gesture	4	astonished	1
# 'for	4	staggered	5	import	6
# fools	1	hardly	3	anticipated	2
# incredibly	1	knowledge	5	art	4
# level	1	five-year-old	1	children	8
# suspended	1	limbs	3	disappointment	2
# vain	1	nodded	2	vivid	2
# thunderclap	1	withdrew	1	bowed	1
# chain	1	flowers	19	received	8
# applause	1	fro	4	laughingly	1
# blossom	1	imagine	10	delicate	3
# culture	1	created	3	someone	1
# exhibited	1	building	8	astonishment	2
# fretted	2	memory	10	confident	2
# profoundly	3	posterity	1	irresistible	2
# entry	1	naturally	5	crowd	4
# yawned	1	shadowy	1	mysterious	2
# tangled	1	neglected	1	weedless	1
# spikes	1	measuring	1	foot	7
# petals	1	variegated	2	shrubs	1
# closely	1	deserted	5	richly	1
# carving	1	narrowly	1	suggestions	1
# decorations	2	broken	10	entered	9
# nineteenth-century	2	grotesque	4	garlanded	1
# soft-colored	1	whirl	1	speech	2
# hall	12	roof	3	windows	7
# glazed	1	coloured	1	unglazed	1
# tempered	1	floor	8	blocks	2
# slabs	2	judged	11	generations	5
# channelled	1	frequented	1	ways	5
# polished	2	heaps	5	fruits	5
# raspberry	1	orange	1	'between	1
# conductors	1	seated	6	themselves	2
# likewise	1	ceremony	1	fruit	5
# stalks	2	openings	2	loath	1
# thirsty	1	hungry	1	surveyed	2
# dilapidated	1	stained-glass	1	geometrical	1
# many	10	places	4	curtains	2
# corner	6	near	9	fractured	1
# effect	3	extremely	3	picturesque	1
# dining	1	watching	6	eating	2
# silky	1	material	3	'fruit	1
# strict	2	vegetarians	1	spite	5
# cravings	1	frugivorous	1	horses	1
# sheep	2	dogs	1	ichthyosaurus	1
# delightful	2	particular	5	season	1
# three-sided	1	husk	1	especially	2
# later	5	perceive	2	'however	1
# checked	1	determined	10	resolute	1
# learn	5	mine	3	interrogative	1
# conveying	1	meaning	4	stare	1
# fair-haired	1	grasp	2	intention	1
# name	5	chatter	2	attempts	1
# immense	1	amount	3	amusement	1
# amidst	2	persisted	1	score	3
# substantives	2	least	8	command	1
# pronouns	1	verb	1	slow	5
# interrogations	1	necessity	9	lessons	1
# inclined	3	indolent	2	fatigued	3
# hosts	1	eager	2	cries	5
# wander	1	toy	1	conversational	1
# ended	3	speedily	4	disregard	1
# sunlit	2	hunger	1	satisfied	1
# distance	6	laugh	2	gesticulated	1
# devices	1	calm	5	scene	2
# glow	2	setting	4	confusing	1
# known	2	situated	1	slope	6
# valley	7	thames	4	shifted	1
# summit	3	crest	5	view	8
# a.d.	1	recorded	1	help	7
# ruinous	4	splendour	1	hill	18
# granite	3	bound	3	masses	5
# labyrinth	1	precipitous	1	walls	4
# pagoda-like	1	plants	6	nettles	1
# tinted	1	leaves	3	incapable	2
# derelict	2	remains	3	structure	3
# destined	3	experience	5	intimation	1
# 'looking	2	terrace	1	rested	2
# houses	4	single	1	household	1
# palace-like	1	cottage	1	form	9
# disappeared	6	communism	1	heels	2
# flash	2	costume	2	hairless	1
# girlish	1	rotundity	1	limb	1
# differences	1	texture	1	mark	1
# alike	1	miniatures	1	parents	1
# physically	1	abundant	8	opinion	1
# security	8	living	7	close	6
# strength	8	softness	1	woman	3
# family	3	differentiation	1	occupations	1
# necessities	2	age	14	physical	10
# population	4	balanced	4	childbearing	1
# evil	2	blessing	1	violence	3
# off-spring	1	secure	5	efficient	2
# needs	8	disappears	1	remind	1
# 'while	2	musing	2	attracted	2
# oddness	1	existing	2	thread	1
# top	2	walking	2	powers	3
# alone	10	adventure	2	yellow	5
# corroded	3	pinkish	2	rust	3
# arm-rests	1	cast	3	griffins	1
# horizon	5	west	3	flaming	1
# horizontal	3	crimson	1	burnished	1
# palaces	4	dotted	1	ruins	10
# obelisk	1	hedges	1	signs	6
# rights	1	evidences	2	agriculture	3
# half-truth	1	facet	1	truth	5
# ruddy	1	mankind	4	realize	2
# social	8	engaged	3	logical	2
# sets	1	premium	2	feebleness	1
# civilizing	1	process	3	makes	3
# climax	1	triumph	8	united	11
# projects	1	deliberately	2	harvest	1
# sanitation	1	stage	1	science	3
# department	1	field	2	spreads	1
# persistently	1	horticulture	1	destroy	4
# cultivate	1	wholesome	2	leaving	4
# fight	4	balance	4	improve	2
# animals	6	few	11	gradually	4
# breeding	2	peach	1	seedless	1
# sweeter	1	flower	1	breed	1
# tentative	1	limited	6	organized	2
# eddies	1	intelligent	2	educated	1
# subjugation	1	wisely	1	vegetable	1
# leaped	1	gnats	1	weeds	1
# everywhere	3	butterflies	1	flew	1
# thither	5	ideal	1	preventive	1
# attained	4	diseases	2	stamped	1
# contagious	1	during	7	stay	2
# putrefaction	1	decay	8	affected	2
# 'social	1	triumphs	1	effected	3
# shelters	1	gloriously	1	clothed	2
# struggle	4	economical	1	shop	1
# traffic	1	commerce	1	constitutes	1
# paradise	1	increasing	4	guessed	2
# inevitably	2	adaptations	1	biological	1
# cause	3	intelligence	7	vigour	1
# active	3	survive	3	weaker	1
# alliance	1	capable	1	self-restraint	1
# decision	1	emotions	1	arise	2
# fierce	2	jealousy	2	tenderness	2
# parental	1	self-devotion	1	justification	1
# dangers	3	_now_	1	sentiment	1
# grow	7	connubial	1	maternity	1
# unnecessary	1	survivals	1	discords	1
# pleasant	7	slightness	1	strengthened	1
# perfect	8	conquest	2	energetic	1
# alter	1	altered	1	'under	1
# restless	5	energy	5	weakness	2
# desires	1	necessary	2	survival	2
# failure	1	love	2	hindrances	1
# war	2	solitary	2	beasts	2
# require	3	constitution	1	weak	5
# outlet	1	surgings	1	purposeless	1
# harmony	2	flourish	2	peace	1
# takes	2	eroticism	1	languor	1
# artistic	2	impetus	1	die	3
# adorn	1	sing	1	sunlight	4
# inactivity	1	keen	2	grindstone	2
# hateful	1	gathering	2	mastered	3
# secret	1	delicious	1	checks	2
# succeeded	1	numbers	3	diminished	2
# abandoned	1	v	1	gibbous	1
# north-east	1	noiseless	1	owl	2
# chill	3	descend	3	find	15
# tangle	3	chilled	1	complacency	1
# leprous	2	conviction	1	lash	1
# grip	1	throat	3	strides	3
# blood	2	trickle	1	certainty	1
# excessive	1	assurance	1	folly	4
# removed	5	reach	4	covered	4
# cursed	1	aloud	3	thereby	1
# stirring	2	moonlit	2	'when	1
# fears	3	cold	8	faced	1
# furiously	2	hidden	3	clutching	2
# mockery	1	dismay	2	consoled	1
# shelter	2	dismayed	1	unsuspected	1
# intervention	1	invention	1	produced	2
# duplicate	1	attachment	1	method	3
# tampering	1	hid	1	startling	1
# clenched	2	fist	3	knuckles	2
# bleeding	1	twigs	3	sobbing	1
# anguish	2	slipped	4	uneven	1
# breaking	2	shin	1	match	18
# inarticulate	1	noises	3	splutter	1
# matches	18	bawling	2	angry	1
# laying	1	shaking	2	sorely	2
# circumstances	5	trying	7	revive	2
# daylight	8	'abruptly	1	knocking	1
# dining-hall	1	moonlight	3	terror	4
# crept	4	unexpected	2	loss	4
# hopelessly	1	raved	1	screaming	1
# god	2	fatigue	2	despair	3
# impossible	3	groping	4	moon-lit	1
# weeping	1	wretchedness	2	misery	2
# woke	2	sparrows	1	within	10
# freshness	3	desertion	1	fairly	4
# behoves	1	patient	2	materials	1
# probably	5	taken	8	hiding-place	3
# scrambled	1	wondering	3	bathe	1
# travel-soiled	1	desire	2	equal	1
# emotion	2	excitement	3	careful	3
# wasted	2	futile	2	questionings	1
# failed	4	stolid	1	jest	2
# task	1	keep	5	impulse	2
# begotten	1	blind	2	anger	1
# curbed	1	advantage	1	perplexity	2
# groove	1	ripped	1	midway	1
# arrival	4	struggled	2	overturned	2
# narrow	7	footprints	2	sloth	1
# block	4	highly	1	decorated	1
# panels	6	rapped	1	hollow	2
# discontinuous	1	frames	1	handles	1
# doors	9	infer	1	inside	2
# blossom-covered	1	apple-trees	1	beckoned	1
# behaved	1	grossly	1	improper	1
# insult	1	sweet-looking	1	chap	1
# temper	1	robe	1	dragging	2
# repugnance	1	beaten	1	banged	1
# chuckle	1	mistaken	1	pebble	1
# flattened	1	coil	1	powdery	1
# hammering	2	gusty	2	outbreaks	1
# furtively	1	occidental	1	vigil	2
# twenty-four	1	hours	2	aimlessly	1
# sit	1	puzzle	1	hopeless	2
# monomania	1	hasty	3	guesses	3
# humour	1	situation	1	spent	2
# anxiety	1	complicated	2	trap	2
# expense	3	'going	1	palace	14
# gates	3	tolerably	1	avoidance	1
# abstain	1	pursuit	1	footing	1
# addition	3	explorations	2	missed	3
# composed	1	concrete	1	verbs	1
# figurative	1	sentences	2	simplest	1
# mystery	6	tethered	1	exuberant	1
# climbed	1	abundance	1	endlessly	1
# style	1	clustering	1	thickets	1
# blossom-laden	1	tree-ferns	1	water	6
# undulating	2	hills	3	serenity	2
# presence	6	depth	1	path	5
# rimmed	1	wrought	1	protected	2
# peering	4	shafted	1	gleam	2
# engine	1	flaring	3	steady	2
# scrap	2	fluttering	2	sucked	1
# towers	2	often	4	flicker	2
# sun-scorched	1	beach	7	extensive	1
# subterranean	3	ventilation	3	difficult	2
# sanitary	1	obvious	1	conclusion	3
# drains	1	bells	1	modes	1
# conveniences	1	visions	1	utopias	1
# arrangements	1	details	1	obtain	4
# imagination	3	inaccessible	3	amid	3
# conceive	1	tale	3	london	4
# central	4	africa	1	tribe	1
# companies	1	movements	3	telephone	1
# wires	1	parcels	1	delivery	1
# postal	1	orders	1	willing	1
# apprehend	1	gap	3	wide	3
# unseen	2	contributed	2	automatic	2
# sepulture	1	crematoria	2	suggestive	1
# cemeteries	1	somewhere	1	range	2
# defeated	1	remark	2	aged	1
# confess	4	satisfaction	2	decadent	2
# difficulties	2	explored	1	dining-halls	1
# machinery	6	appliances	3	fabrics	1
# undecorated	1	complex	2	specimens	3
# vestige	2	creative	1	shops	1
# importations	1	playing	1	bathing	3
# fashion	4	waterless	1	pillars	3
# clue	3	inscription	2	excellent	2
# letters	1	third	2	visit	3
# sort	1	shallow	2	cramp	1
# downstream	1	main	3	strongly	1
# swimmer	1	deficiency	1	slightest	1
# weakly	1	drowning	1	hurriedly	1
# poor	4	mite	1	safe	5
# estimate	1	gratitude	2	afternoon	5
# centre	3	exploration	2	delight	3
# desolate	3	rate	3	best	5
# appreciation	1	gift	1	arbour	1
# smiles	1	friendliness	1	kissed	1
# weena	52	appropriate	1	friendship	1
# 'she	3	heart	4	tire	1
# plaintively	1	problems	3	carry	5
# flirtation	1	distress	2	expostulations	1
# frantic	1	trouble	4	devotion	1
# affection	3	cling	1	inflicted	1
# seeming	1	fond	1	showing	1
# doll	1	return	7	neighbourhood	1
# fearless	1	oddest	1	threatening	1
# dreaded	5	passionate	3	observing	1
# droves	1	enter	3	tumult	2
# blockhead	1	lesson	2	insisted	1
# multitudes	1	troubled	2	triumphed	1
# acquaintance	1	including	10	pillowed	1
# awakened	2	dawn	4	dreaming	1
# drowned	1	sea	13	anemones	1
# greyish	1	chamber	1	colourless	3
# virtue	1	sunrise	1	dying	2
# mingled	1	half-light	1	inky	2
# cheerless	1	ghosts	4	scanned	2
# ape-like	2	quickly	1	leash	1
# uncertain	1	early-morning	1	doubted	1
# colouring	1	returned	7	keenly	1
# dated	1	notion	2	grant	1
# amused	1	generation	2	argued	1
# theory	6	hence	2	unsatisfying	1
# indefinite	2	search	2	substitute	1
# hotter	3	assume	3	cooling	1
# younger	1	darwin	1	forget	1
# parent	1	catastrophes	1	occur	2
# renewed	2	inner	2	suffered	1
# heat	6	glare	8	ruin	4
# clambering	5	masonry	2	gallery	19
# fallen	7	contrast	1	brilliancy	1
# impenetrably	1	blackness	11	spots	3
# halted	3	spellbound	1	instinctive	1
# glaring	2	eyeballs	1	overcoming	1
# advanced	2	ill-controlled	1	darted	1
# blundered	1	beneath	3	pile	2
# imperfect	1	greyish-red	1	flaxen	1
# all-fours	1	forearms	1	obscurity	3
# pillar	2	shaft	8	retreated	2
# spider	2	rests	1	forming	1
# fingers	5	dropped	3	monster	3
# persuading	1	dawned	1	species	6
# upper-world	6	sole	2	descendants	2
# obscene	2	nocturnal	2	heir	1
# underground	7	suspect	2	wondered	2
# scheme	1	related	1	upper-worlders	3
# solution	2	withal	1	amorous	1
# male	1	pursued	2	female	1
# distressed	2	considered	1	bad	1
# visibly	1	interested	1	amuse	1
# sliding	2	ventilating	2	hint	2
# economic	1	'here	1	emergence	1
# habit	5	live	4	largely	3
# kentucky	1	caves	2	capacity	1
# witness	2	cat	1	evident	2
# fumbling	1	awkward	1	flight	4
# reinforced	1	sensitiveness	1	retina	1
# tunnelled	1	enormously	1	tunnellings	1
# universal	2	ramifications	1	artificial	2
# _how_	1	splitting	2	anticipate	1
# gradual	2	widening	3	temporary	1
# labourer	1	key	1	wildly	1
# ornamental	1	purposes	1	metropolitan	1
# railways	1	subways	1	workrooms	1
# multiply	1	increased	3	industry	2
# deeper	3	factories	1	spending	1
# east-end	1	worker	1	practically	2
# exclusive	2	due	3	refinement	1
# gulf	2	rude	1	closing	3
# prettier	1	country	5	shut	1
# higher	2	educational	2	facilities	1
# habits	1	exchange	1	class	2
# intermarriage	1	retards	1	lines	1
# frequent	1	haves	1	pursuing	1
# have-nots	1	workers	1	adapted	3
# pay	3	rent	1	caverns	1
# starve	1	suffocated	1	arrears	1
# miserable	1	rebellious	1	permanent	2
# happy	1	theirs	1	etiolated	1
# moral	1	co-operation	1	imagined	1
# armed	1	perfected	1	working	2
# fellow-man	2	cicerone	1	utopian	1
# supposition	1	zenith	1	too-perfect	1
# dwindling	1	size	3	under-grounders	1
# called	3	modification	2	eloi	8
# doubts	1	masters	1	restore	1
# under-world	8	disappointed	1	answer	1
# unendurable	1	harshly	1	burst	3
# concerned	1	banishing	1	inheritance	1
# vi	1	new-found	1	manifestly	1
# pallid	1	bodies	1	half-bleached	1
# preserved	4	zoological	1	museum	5
# sympathetic	1	influence	1	disgust	1
# oppressed	1	definite	1	noiselessly	1
# appearances	1	whitened	1	lemurs	1
# replaced	1	shirks	1	duty	1
# penetrating	1	mysteries	1	companion	1
# clamber	2	appalled	1	restlessness	1
# afield	1	exploring	2	expeditions	1
# combe	1	wood	15	observed	1
# character	3	largest	1	facade	1
# lustre	1	pale-green	1	tint	1
# chinese	1	porcelain	10	aspect	1
# push	3	tiring	1	circuit	1
# caresses	1	regarding	2	piece	2
# enable	1	shirk	1	descent	4
# danced	1	strangely	1	disconcerted	1
# kissing	2	parapet	2	climbing	2
# feared	3	leak	2	amazement	2
# pull	1	opposition	1	nerved	1
# roughly	1	agonized	1	reassure	1
# clung	3	yards	2	projecting	3
# lighter	1	cramped	2	weight	2
# acutely	1	quick	2	glancing	1
# disk	4	star	3	projection	1
# louder	2	oppressive	2	agony	2
# relief	1	slender	1	loophole	1
# tunnel	3	lie	3	ached	1
# unbroken	2	distressing	1	throb	3
# pumping	1	roused	1	snatched	1
# retreating	1	impenetrable	1	abnormally	1
# pupils	1	abysmal	1	fishes	1
# rayless	2	apart	1	order	4
# vanishing	1	gutters	1	tunnels	1
# strangest	1	over-world	2	unaided	1
# cavern	1	stretched	2	burning	5
# dimness	3	spectral	1	sheltered	1
# halitus	1	freshly	1	shed	1
# meal	1	carnivorous	1	survived	1
# joint	1	heavy	2	smell	3
# lurking	2	stung	1	wriggling	2
# ill-equipped	1	absurd	1	assumption	1
# ourselves	2	frightfully	2	kodak	1
# weapons	1	endowed	1	safety-matches	1
# run	3	economize	2	box	6
# novelty	1	lank	1	odour	2
# disengaged	2	plucking	1	clothing	1
# ignorance	2	shouted	3	loudly	1
# whispering	1	discordantly	1	alarmed	1
# escape	3	protection	2	eking	1
# pattering	4	hurried	1	mistaking	1
# waved	1	nauseatingly	1	chinless	1
# pinkish-grey	1	blindness	2	bewilderment	2
# giddy	2	grasped	3	tugged	1
# clutches	1	stayed	3	blinking	3
# well-nigh	1	secured	1	boot	1
# climb	1	twenty	1	thirty	4
# nausea	2	greatest	1	keeping	3
# faintness	2	swam	2	well-mouth	1
# soil	1	smelt	1	clean	1
# vii	1	worse	1	sustaining	1
# discoveries	2	impeded	1	simplicity	1
# overcome	1	element	2	sickening	1
# loathed	1	pit	3	beast	1
# incomprehensible	1	remarks	1	guess	1
# degree	1	villainy	1	hypothesis	2
# mechanical	3	resulted	1	evolution	1
# relationship	1	carolingian	1	kings	1
# futility	2	possessed	2	sufferance	1
# intolerable	1	inferred	1	maintained	1
# service	2	horse	1	paws	1
# killing	5	ancient	2	departed	2
# organism	1	reversed	1	nemesis	1
# apace	2	thousands	7	thrust	2
# begun	1	anew	1	becoming	1
# floated	1	stirred	1	meditations	1
# familiar	6	differently	2	ours	1
# prime	1	paralyse	1	terrors	2
# delay	1	fastness	1	refuge	4
# realizing	1	exposed	1	shuddered	1
# commended	1	practicable	1	dexterous	1
# judge	3	pinnacles	2	south-west	2
# eighteen	1	moist	1	distances	1
# heel	4	shoes	4	nail	1
# lame	2	silhouetted	1	'weena	2
# delighted	1	desired	1	occasionally	2
# pick	1	concluded	1	eccentric	1
# floral	1	decoration	1	utilized	1
# reminds	1	jacket	2	paused	1
# withered	2	unlike	2	mallows	1
# hush	1	wimbledon	1	contrived	1
# breeze	3	stops	1	expectation	2
# darkling	3	senses	1	preternaturally	1
# hollowness	1	ant-hill	1	receive	4
# burrows	1	declaration	1	deepened	1
# waded	1	opposite	1	statue	1
# _minus_	1	acacias	1	darker	2
# brow	1	spreading	2	sore	1
# hide	1	dense	1	branches	3
# stumble	1	tree-boles	1	excitements	2
# glad	2	asleep	1	wrapped	1
# constellations	2	imperceptible	1	lifetimes	1
# groupings	1	milky	1	streamer	1
# yore	1	southward	1	sirius	1
# kindly	1	dwarfed	1	troubles	1
# terrestrial	1	unfathomable	1	precessional	1
# pole	1	describes	1	forty	2
# revolutions	1	activity	1	traditions	1
# nations	1	languages	1	literatures	1
# ancestry	1	shiver	1	starlike	1
# 'through	1	whiled	1	dozed	1
# peaked	1	overtaking	1	overflowing	1
# unreasonable	2	swollen	1	ankle	1
# wherewith	1	break	2	dainty	1
# pitied	1	feeble	2	rill	1
# long-ago	1	food	2	rats	2
# discriminating	1	monkey	1	prejudice	1
# instinct	2	sons	1	cannibal	1
# fatted	1	ant-like	1	preyed	1
# rigorous	1	punishment	1	selfishness	1
# labours	1	watchword	2	excuse	1
# carlyle-like	1	scorn	1	wretched	1
# claim	2	sympathy	1	perforce	2
# pursue	1	contrive	2	immediate	4
# weapon	3	torch	1	arrange	1
# battering	1	ram	1	persuasion	2
# schemes	1	chosen	1	dwelling	1
# noon	1	ragged	1	vestiges	3
# north-eastward	3	surprised	3	estuary	1
# wandsworth	1	battersea	1	happening	1
# foolishly	1	interpret	1	'within	2
# customary	1	tiled	1	array	4
# objects	1	shrouded	1	covering	2
# skeleton	2	oblique	1	extinct	2
# upper	2	bones	2	rain-water	1
# brontosaurus	1	confirmed	2	sloping	3
# clearing	1	cases	3	air-tight	3
# contents	2	latter-day	1	south	2
# palaeontological	1	section	9	fossils	2
# bacteria	1	ninety-nine	1	hundredths	1
# slowness	1	treasures	1	traces	3
# threaded	1	strings	1	reeds	1
# bodily	1	deadened	1	footsteps	1
# monument	1	preoccupation	1	receded	2
# palaeontology	1	historical	1	galleries	1
# vastly	1	interesting	1	spectacle	1
# geology	1	transversely	1	minerals	1
# gunpowder	1	saltpeter	1	nitrates	1
# deliquesced	1	train	1	specialist	1
# aisle	2	parallel	1	history	1
# shrivelled	2	blackened	1	stuffed	1
# mummies	1	jars	1	sorry	3
# readjustments	1	proportions	1	ill-lit	1
# intervals	1	globes	1	ceiling	1
# originally	1	artificially	1	bulks	1
# puzzles	2	vaguest	1	solve	1
# sloped	1	footnote	1	hill.	1
# slit-like	1	area	1	puzzling	1
# diminution	1	apprehensions	1	revived	1
# projected	1	signal-box	1	stand	2
# whimper	1	correctly	1	snapped	1
# rejoined	1	mace	4	sufficient	2
# encounter	1	longed	1	kill	1
# slake	1	thirst	1	murder	1
# restrained	2	brutes	3	military	1
# flags	1	charred	2	rags	1
# semblance	1	print	2	warped	1
# clasps	1	literary	14	moralized	1
# keenest	1	enormous	1	wilderness	1
# testified	2	_philosophical	1	transactions_	1
# optics	1	technical	1	chemistry	1
# eagerly	2	damp	1	carpeting	1
# composite	1	whistling	1	_the	1
# _cancan_	1	skirt-dance	1	tail-coat	1
# original	2	inventive	1	escaped	2
# immemorial	1	fortunate	1	unlikelier	1
# sealed	2	chance	1	hermetically	1
# wax	1	accordingly	2	unmistakable	1
# centuries	2	sepia	1	painting	1
# belemnite	1	perished	1	fossilized	1
# throw	1	inflammable	1	explosives	1
# crowbar	3	helpful	1	elated	1
# hatchet	1	sword	1	promised	2
# pistols	1	rifles	1	cartridges	2
# rotted	1	shattered	1	idols	1
# mexican	1	grecian	1	yielding	1
# nose	1	steatite	1	america	1
# exhibits	1	lignite	1	fresher	1
# merest	1	accident	1	dynamite	1
# joy	1	selecting	1	essay	1
# chances	1	non-existence	1	court	1
# fruit-trees	1	refreshed	1	consider	2
# needed	1	refrained	1	forcing	1
# ix	1	'we	1	ere	1
# pushing	1	woods	2	sticks	4
# grass	5	litter	1	thus	2
# slower	11	sleepiness	1	shrubby	1
# singular	1	impending	1	calamity	2
# warning	1	onward	1	feverish	1
# scrub	1	insidious	1	approach	2
# calculated	2	safer	1	resting-place	1
# firewood	1	reluctantly	1	amaze	1
# atrocious	1	ingenious	1	temperate	1
# burn	1	focused	1	dewdrops	1
# districts	1	lightning	1	blast	1
# gives	2	widespread	1	vegetation	2
# fermentation	1	decadence	1	fire-making	1
# licking	1	play	1	herself	1
# plunged	1	crowded	1	stems	3
# curved	2	accustomed	2	avoid	1
# crackling	2	rustle	1	blood-vessels	1
# tug	1	fumbled	2	scratched	1
# backs	2	lump	2	prepared	1
# fright	1	stooped	2	breathe	1
# flared	1	knelt	1	lifted	1
# manoeuvring	1	sweat	1	rapidly	1
# encamp	1	bole	1	collecting	1
# forms	1	blinded	1	grind	1
# bonfire	1	dry	2	foliage	2
# choking	1	smoky	1	dead	2
# beat	3	moreover	1	replenishing	1
# slumbrous	2	nod	1	clinging	2
# bitterness	1	death	2	soul	1
# heaped	1	monstrous	2	web	7
# nipping	1	rolled	1	succulent	1
# bone	1	blows	2	exultation	1
# fighting	1	tree	4	pitch	1
# incessant	1	stream	1	reddish	3
# spark	1	starlight	2	roar	1
# flames	4	explosive	1	outflanked	1
# hillock	3	tumulus	1	surmounted	1
# hawthorn	2	writhing	1	encircling	1
# crippling	1	moans	1	helplessness	1
# quivering	1	elude	1	somewhat	1
# uncanny	1	coiling	1	uprush	1
# tatters	1	canopy	1	belonged	1
# fists	1	persuaded	1	screamed	1
# thrice	1	rush	1	subsiding	2
# whitening	1	blackening	1	stumps	1
# searched	1	relieved	1	awful	2
# abominations	1	island	1	haze	1
# remnant	1	souls	1	moaning	2
# tied	1	limped	1	smoking	2
# pulsated	1	internally	1	intensest	1
# sorrow	1	dream	7	lonely	2
# thoughts	1	longing	1	trouser	1
# x	1	'about	1	nine	1
# conclusions	1	bitterly	1	magnificent	1
# banks	1	gay	1	saved	1
# blots	1	cupolas	1	enemies	1
# grieved	1	committed	2	permanency	2
# property	3	safety	1	wealth	1
# unemployed	1	unsolved	1	law	3
# compensation	1	environment	1	appeals	1
# partake	1	meet	3	variety	2
# perfection	1	feeding	1	disjointed	1
# retained	1	initiative	1	forbidden	2
# wit	1	invent	1	fatigues	1
# tranquil	1	sleepy	1	theorizing	1
# catching	1	refreshing	1	awoke	1
# napping	1	stretching	1	slid	2
# apartment	1	elaborate	1	preparations	1
# meek	1	surrender	1	suppressing	1
# stepped	1	oiled	1	cleaned	1
# trapped	1	chuckled	1	gleefully	1
# calmly	1	fix	2	depart	1
# sweeping	3	scramble	2	persistent	1
# fitted	2	butt	1	ring	1
# xi	1	sickness	1	properly	1
# unheeding	1	amazed	1	dial	2
# reversing	1	indicators	1	seconds	1
# prodigious	1	indicative	1	marked	3
# stretch	1	brooded	1	comet	1
# given	2	dome	2	glowing	2
# glowed	1	reverted	1	sullen	1
# tidal	1	drag	1	cautiously	1
# scale	1	outlines	1	indian	1
# south-eastward	1	scarlet	1	hull	1
# intensely	2	south-eastern	1	lichen	1
# wan	1	breakers	1	waves	1
# swell	1	gentle	1	eternal	2
# broke	1	incrustation	2	lurid	1
# mountaineering	1	rarefied	1	'far	1
# butterfly	1	slanting	1	hillocks	2
# firmly	1	crab-like	1	crab	2
# uncertainly	1	claws	2	antennae	1
# whips	1	waving	1	stalked	1
# corrugated	1	ornamented	1	ungainly	2
# greenish	1	blotched	1	sinister	1
# crawling	4	tickling	1	fly	1
# ear	1	threadlike	1	qualm	1
# alive	1	algal	1	slime	2
# monsters	2	dozens	1	foliated	1
# northward	1	stony	1	slow-stirring	1
# lichenous	1	hurts	1	lungs	1
# duller	2	earthy	1	crustacea	1
# fascination	1	ebb	1	million	2
# obscure	1	tenth	1	multitude	1
# livid	1	liverworts	1	lichens	1
# flecked	1	bitter	1	assailed	1
# fringes	1	ice	1	expanse	1
# bloody	1	unfrozen	1	indefinable	1
# flopping	1	bank	1	deceived	1
# outline	1	concavity	1	bay	1
# aghast	1	eclipse	2	transit	1
# gusts	1	east	1	showering	1
# whisper	1	bleating	1	birds	1
# background	1	thickened	1	peaks	1
# overcame	1	bow	1	sick	2
# football	1	bigger	1	trailed	1
# blood-red	1	fitfully	1	fainting	1
# sustained	1	clambered	1	xii	1
# ebbed	1	flowed	1	spun	1
# slackened	1	starting-point	1	flapped	1
# mrs	1	inversion	1	glided	1
# previously	1	hillyer	1	shakily	1
# calmer	1	around	1	south-east	1
# brain	1	stagnant	1	begrimed	1
# mall	1	gazette_	1	timepiece	1
# sniffed	1	washed	1	dined	1
# prophecy	1	speculating	1	destinies	1
# fiction	1	assertion	1	stroke	1
# nervously	1	grate	1	creak	1
# carpet	1	audience	1	absorbed	1
# sixth	1	sigh	1	're	1
# stories	1	puffing	1	mute	1
# half-healed	1	scars	1	gynaeceum	1
# specimen	2	hanged	1	'how	1
# cabs	1	station	1	eluded	1
# fit	1	squat	2	ugly	1
# translucent	1	glimmering	1	smears	1
# awry	1	damaged	2	hesitation	1
# shared	2	cab	1	'gaudy	1
# credible	1	sober	1	substantial-looking	1
# shaken	1	instability	1	meddle	1
# knapsack	1	elbow	1	shake	1
# 'with	1	hoax	1	awfully	1
# lunch	1	prove	1	hilt	1
# consented	1	comprehending	1	slam	1
# richardson	2	publisher	1	barely	1
# handle	1	exclamation	1	truncated	1
# ghostly	1	whirling	1	phantasm	1
# pane	1	skylight	1	man-servant	1
# disappointing	1	photographs	1	lifetime	1
# knows	1	epilogue	1	choose	2
# hairy	1	savages	1	unpolished	1
# cretaceous	1	saurians	1	reptilian	1
# phrase	5	wandering	1	plesiosaurus-haunted	1
# coral	1	reef	1	saline	1
# triassic	1	riddles	1	wearisome	1
# manhood	1	fragmentary	1	mutual	2
# culminating	1	discussed	1	cheerlessly	1
# makers	1	casual	1	brittle	1
# file	2	named	1	35.txt	1
# files	2	various	1	formats	2
# //www.gutenberg.net/3/35/	1	editions	4	replace	1
# creating	4	works	32	public	9
# owns	2	states	14	copyright	13
# distribute	6	permission	7	paying	2
# rules	2	apply	1	copying	4
# gutenberg-tm	57	electronic	27	protect	2
# trademark	10	charge	6	ebooks	7
# copies	7	complying	3	creation	1
# performances	1	research	2	modified	1
# redistribution	2	subject	1	commercial	1
# mission	4	promoting	2	distribution	6
# agree	9	comply	6	available	2
# 1	2	redistributing	2	1.a	1
# indicate	1	trademark/copyright	1	agreement	18
# cease	1	paid	6	fee	8
# access	10	refund	10	entity	3
# 1.e.8	4	1.b	1	1.c	2
# archive	13	pglaf	1	compilation	1
# located	4	prevent	1	performing	3
# based	2	references	2	sharing	1
# format	4	attached	1	share	1
# laws	8	govern	1	countries	1
# downloading	1	concerning	2	status	4
# sentence	2	links	3	prominently	2
# accessed	1	copied	2	distributed	4
# derived	1	contain	2	indicating	1
# holder	4	fees	4	charges	1
# appearing	1	requirements	4	paragraphs	3
# 1.e.9	3	1.e.3	1	additional	4
# linked	1	1.e.4	1	unlink	1
# remove	1	containing	1	1.e.5	1
# redistribute	1	1.e.6	1	convert	1
# compressed	1	nonproprietary	1	processing	1
# provide	7	vanilla	2	ascii	2
# version	1	site	4	user	3
# request	1	alternate	1	include	1
# viewing	1	-	7	royalty	3
# %	1	gross	1	profits	1
# calculate	1	applicable	3	taxes	1
# owner	5	donate	3	payments	3
# prepare	2	legally	1	periodic	1
# returns	1	address	1	4	3
# donations	15	notifies	1	e-mail	1
# receipt	2	s/he	1	medium	5
# accordance	2	1.f.3	4	replacement	5
# reported	1	90	2	michael	2
# 1.f	1	1.f.1	1	volunteers	6
# expend	1	identify	1	transcribe	1
# despite	1	stored	1	defects	1
# corrupt	1	data	1	transcription	1
# defective	3	computer	2	virus	1
# damage	2	equipment	3	1.f.2	1
# disclaimer	3	damages	4	party	1
# liability	3	costs	2	expenses	2
# remedies	1	negligence	1	breach	2
# f3	1	distributor	1	liable	1
# indirect	1	consequential	1	punitive	1
# receiving	1	sending	1	written	3
# lieu	2	electronically	2	opportunity	1
# opportunities	1	1.f.4	1	'as-is	1
# implied	2	merchantibility	1	fitness	1
# allow	1	disclaimers	1	exclusion	1
# types	1	violates	1	interpreted	1
# invalidity	1	unenforceability	1	provision	1
# remaining	1	provisions	1	1.f.6	1
# indemnify	1	agent	1	employee	1
# harmless	1	directly	1	indirectly	1
# alteration	1	additions	1	deletions	1
# synonymous	1	readable	2	widest	2
# obsolete	1	middle-aged	1	exists	1
# walks	1	financial	1	assistance	1
# goals	1	ensuring	1	2001	1
# //www.pglaf.org	1	non	1	profit	1
# corporation	1	mississippi	1	granted	1
# internal	1	revenue	1	ein	1
# identification	1	64-6221541	1	letter	1
# contributions	2	deductible	1	u.s.	2
# office	2	4557	1	melan	1
# s	1	fairbanks	1	ak	1
# throughout	1	numerous	1	locations	2
# north	1	1500	1	lake	1
# ut	1	84116	1	801	1
# email	3	@	2	pglaf.org	2
# gregory	1	b.	1	newby	1
# executive	1	director	1	gbnewby	1
# licensed	1	accessible	1	outdated	1
# 5,000	1	important	1	maintaining	1
# regulating	1	charities	1	charitable	1
# paperwork	1	solicit	2	confirmation	1
# solicitation	1	prohibition	1	accepting	1
# donors	1	offers	1	international	1
# statements	1	treatment	1	swamp	1
# pages	1	donation	1	methods	1
# credit	1	card	1	//pglaf.org/donate	1
# s.	1	originator	1	network	1
# u.s	1	necessarily	1	pg	1
# //www.gutenberg.net	1	includes	1	produce	1

# %% [markdown]
# ### Exercise 2
# Turn the output of map_reduce (i.e., results) into a Pandas dataframe  or a dictionary.  Then
# 1. look up the number of times 'time' occurs.
# 2. find all of the words which occur more than 200 times

# %%
import pandas as pd

df =pd.DataFrame(results,columns=["word","count"])
df[df["word"]=="time"]
# Out:
#    word  count
# 4  time    201

# %%
df[df["count"]>200]
# Out:
#      word  count
# 3     the   2419
# 4    time    201
# 6       ,   2372
# 18    for    243
# 20     of   1268
# 23     at    253
# 26    and   1303
# 27   with    262
# 31      .   1882
# 35     it    432
# 68      i   1266
# 74     to    760
# 77    was    551
# 79      a    872
# 100    in    594
# 105  that    447
# 139    as    271
# 151    me    281
# 170     '    248
# 398    my    437
# 487   had    355

# %%
#alternative without pandas

def list_to_dict(alist):
    adict={}
    for (k,v) in alist:
        adict[k]=v
    return adict

resultsdict=list_to_dict(results)
print("time: "+str(resultsdict['time']))


def morethan(adict,threshold):
    alist=[]

    for (key,value) in resultsdict.items():
        if value>threshold:
            alist.append((key,value))
    return alist

print(morethan(resultsdict,200))
# Out:
# time: 201
# [('the', 2419), ('time', 201), (',', 2372), ('for', 243), ('of', 1268), ('at', 253), ('and', 1303), ('with', 262), ('.', 1882), ('it', 432), ('i', 1266), ('to', 760), ('was', 551), ('a', 872), ('in', 594), ('that', 447), ('as', 271), ('me', 281), ("'", 248), ('my', 437), ('had', 355)]

# %% [markdown]
# Here is some code which uses a pool of processes to do the map tasks and reduce tasks.  A slight modification is needed for the map and reduce functions so that they return lists rather than the 'unpickleable' generators.

# %%
#import operator
from multiprocessing import Pool

def map_reduce_parallel(inputs,mapper,reducer,mapprocesses=3,reduceprocesses=2):
    
    collector=defaultdict(list)  #this dictionary is where we will store intermediate results
                                 #it will map keys to lists of values (default value of a list is [])
                                 #in a real system, this would be stored in individual files at the map nodes
                                 #and then transferred to the reduce nodes
    
    mappool = Pool(processes=mapprocesses)
    #map stage
    
    mapresults=mappool.map(mapper,inputs)
    mappool.close()
    #print mapresult
    for mapresult in mapresults:
        for (key, value) in mapresult:     #pass each input to the mapper function and receive back each key,value pair yielded
            collector[key].append(value)     #append the value to the list for that key in the intermediate store
            
    #reduce stage 
    outputs=[]
    reducepool = Pool(processes=reduceprocesses)
    
    reduceresults=reducepool.map(reducer,collector.items())
    reducepool.close()
    for reduceresult in reduceresults:
        outputs+=reduceresult
   
    return outputs

# %%
import defs  # auxiliary python program with the map and reduce functions: defs.py 
             
# Here are these functions, commented out, for your information:

# def wc_mapper_parallel(document):
#     output=[]
#     for word in document:
#         output.append((word,1))
        
#     return output

# def wc_reducer_parallel(item):
#     output=[]
#     (word,counts)=item
#     output.append((word,sum(counts)))
#     return output
        
results=map_reduce_parallel(lines,defs.wc_mapper_parallel,defs.wc_reducer_parallel)
#results
df=pd.DataFrame(results,columns=["word","count"])
df[df["word"]=="time"]
# Out:
#    word  count
# 4  time    201

# %% [markdown]
# ### Exercise 3
# Time the performance of the parallel version of map_reduce with different numbers of map and reduce processes.
# * What is the best number of processes for each stage on the computer you are working on?
# * How fast is the original non-parallel version of map_reduce?
# * Explain why this is significantly different to the parallel version (with 1 process at each stage).

# %%
import numpy as np
import time

def timeit(somefunc,*args,**kwargs):
    times=[]
    repeats=100
    for i in range(repeats):
        starttime=time.time()
        ans=somefunc(*args,**kwargs)
        endtime=time.time()
        timetaken=endtime-starttime
        times.append(timetaken)
    
    mean=np.mean(times)
    stdev=np.std(times)
    error=stdev/(repeats**0.5)
 
    return (ans,mean,error)

# %%
ans,mean,sd=timeit(map_reduce,lines,wc_mapper,wc_reducer)
print(mean,sd)
# Out:
# 0.011469218730926514 0.0007166078252461874

# %%
ans,mean,sd=timeit(map_reduce_parallel,lines,defs.wc_mapper_parallel,defs.wc_reducer_parallel,mapprocesses=1,reduceprocesses=1)
print(mean,sd)
# Out:
# 0.1261836338043213 0.008532408635731558

# %%
ans,mean,sd=timeit(map_reduce_parallel,lines,defs.wc_mapper_parallel,defs.wc_reducer_parallel,mapprocesses=2,reduceprocesses=1)
print(mean,sd)
# Out:
# 0.11331103563308716 0.007615309586743195

# %%
ans,mean,sd=timeit(map_reduce_parallel,lines,defs.wc_mapper_parallel,defs.wc_reducer_parallel,mapprocesses=1,reduceprocesses=2)
print(mean,sd)
# Out:
# 0.11699332475662232 0.007705948549100209

# %%
ans,mean,sd=timeit(map_reduce_parallel,lines,defs.wc_mapper_parallel,defs.wc_reducer_parallel,mapprocesses=3,reduceprocesses=1)
print(mean,sd)
# Out:
# 0.11308610439300537 0.007416591036939156

# %%
ans,mean,sd=timeit(map_reduce_parallel,lines,defs.wc_mapper_parallel,defs.wc_reducer_parallel,mapprocesses=2,reduceprocesses=2)
print(mean,sd)
# Out:
# 0.09655795812606811 0.0054101573922414395

# %%
ans,mean,sd=timeit(map_reduce_parallel,lines,defs.wc_mapper_parallel,defs.wc_reducer_parallel,mapprocesses=3,reduceprocesses=2)
print(mean,sd)
# Out:
# 0.09799331188201904 0.005302156288125585

# %% [markdown]
# On my laptop, the version involving multiprocessing is slower, showing how big the time overhead can be in setting up a parallel computing environment. However, if you are using a parallel computing environment, then the results do show that making use of more than 1 map/reduce process does speed things up a bit. For heavier tasks than this one, there will be more benefit to parallel computing.

# %% [markdown]
# ### Exercise 4
# Write some map and reduce functions of your own.  Maybe ...
# 1. the frequency of each length of word
# 2. the mean length of a word beginning with each letter
# 3. matrix-vector multiplication
# 4. matrix-matrix multiplication

# %% [markdown]
# **In the below, I put the map and reduce functions into this notebook. However, there is a chance that this won't work for everyone's Python set-up. If you find this is the case, then you need to put the map and reduce functions into an auxiliary .py file, as above for the word counting.**

# %%
#frequency of each length of word

def length_mapper_parallel(document):
    output=[]
    for word in document:
        output.append((len(word),1))
        
    return output

def length_reducer_parallel(item):
    output=[]
    (word,counts)=item
    output.append((word,sum(counts)))
    return output

        

results=map_reduce_parallel(lines,length_mapper_parallel,length_reducer_parallel)
length_df=pd.DataFrame(results,columns=["length","count"])
length_df.head(10)
# Out:
#    length  count
# 0       8   1553
# 1       9   1192
# 2       2   6100
# 3       3   7932
# 4       4   6199
# 5       7   2478
# 6       1   7081
# 7       6   2779
# 8       5   3855
# 9      12    302

# %%
#mean length of word

def mean_mapper_parallel(document):
    output=[]
    for word in document:
        output.append((word[0],len(word)))
        
    return output

def mean_reducer_parallel(item):
    output=[]
    (character,lengths)=item
    output.append((character,np.mean(lengths)))
    return output

        

results=map_reduce_parallel(lines,mean_mapper_parallel,mean_reducer_parallel)
mean_df=pd.DataFrame(results,columns=["initial","mean"])
mean_df.head(10)
# Out:
#   initial      mean
# 0       ﻿  8.000000
# 1       g  6.212538
# 2       '  2.824850
# 3       t  3.820648
# 4       m  4.222620
# 5       ,  1.000000
# 6       b  4.737043
# 7       h  4.121680
# 8       (  1.000000
# 9       )  1.000000

# %%
v=[1,2,3,4]
m=[[1,2,3,4],[2,3,4,5],[3,4,5,6],[4,5,6,7]]

v_array=np.array(v)
m_array=np.array(m)

m_array.dot(v_array.T)
# Out:
# array([30, 40, 50, 60])

# %%
def matrixvector_mapper(inp):
    (i,j,mij,v)=inp
    return([(i,mij*v[j])])

def matrixvector_reducer(item):
    (key,values)=item
    output=[(key,sum(values))]
    return output

def mapreduce_matrixvector(m,v,mp=3,rp=2):
    
    items=[]
    for i,row in enumerate(m):
        for j,item in enumerate(row):
            items.append((i,j,m[i][j],v))
    return map_reduce_parallel(items,matrixvector_mapper,matrixvector_reducer,mapprocesses=mp,reduceprocesses=rp)

mvresults=mapreduce_matrixvector(m,v)
print(mvresults)
# Out:
# [(0, 30), (1, 40), (2, 50), (3, 60)]

# %%
ans,mean,sd=timeit(mapreduce_matrixvector,m,v,mp=2,rp=1)
print(mean,sd)
# Out:
# 0.018314309120178222 0.00017813431201346285

# %%
ans,mean,sd=timeit(mapreduce_matrixvector,m,v,mp=1,rp=1)
print(mean,sd)
# Out:
# 0.016373491287231444 8.877683017237075e-05

# %%
v_array=np.array(v)
m_array=np.array(m)
m_array.dot(m_array)
# Out:
# array([[ 30,  40,  50,  60],
#        [ 40,  54,  68,  82],
#        [ 50,  68,  86, 104],
#        [ 60,  82, 104, 126]])

# %%
#matrix multiplication

def mm_mapper1(item):
    (mat,i,j,mij)=item
    
    if mat=='M':
        output=[(j,('M',i,mij))]
    else:
        output=[(i,('N',j,mij))]
        
    return output
        
def mm_reducer1(item):
    #print(item)
    (key,values)=item
    Ms=[]
    Ns=[]
    for value in values:
        if value[0]=='M':
            Ms.append((value[1],value[2]))
        else:
            Ns.append((value[1],value[2]))
    output=[]        
    for (i,m) in Ms:
        for (k,n) in Ns:
            output.append(((i,k),m*n))
    return output

def mm_mapper2(item):
    return [item]

def mm_reducer2(item):
    
    (key,values)=item
    output=[(key,sum(values))]
    return output


def mapreduce_matrixmult(m,n,mp=3,rp=2):
    items=[]
    for i,row in enumerate(m):
        for j, item in enumerate(row):
            items.append(('M',i,j,m[i][j]))
            
    for i,row in enumerate(n):
        for j,item in enumerate(row):
            items.append(('N',i,j,n[i][j]))
    #print(items)        
    pass1=map_reduce_parallel(items,mm_mapper1,mm_reducer1,mapprocesses=mp,reduceprocesses=rp)
    return map_reduce_parallel(pass1,mm_mapper2,mm_reducer2,mapprocesses=mp,reduceprocesses=rp)

# %%
mapreduce_matrixmult(m,m)
# Out:
# [((0, 0), 30),
#  ((0, 1), 40),
#  ((0, 2), 50),
#  ((0, 3), 60),
#  ((1, 0), 40),
#  ((1, 1), 54),
#  ((1, 2), 68),
#  ((1, 3), 82),
#  ((2, 0), 50),
#  ((2, 1), 68),
#  ((2, 2), 86),
#  ((2, 3), 104),
#  ((3, 0), 60),
#  ((3, 1), 82),
#  ((3, 2), 104),
#  ((3, 3), 126)]

# %%
ans,mean,sd=timeit(mapreduce_matrixmult,m,m,mp=1,rp=1)
print(mean,sd)
# Out:
# 0.032625267505645754 0.0001310789039645563

# %%
ans,mean,sd=timeit(mapreduce_matrixmult,m,m,mp=2,rp=1)
print(mean,sd)
# Out:
# 0.037695558071136476 0.00016486395583180095

# %%
ans,mean,sd=timeit(mapreduce_matrixmult,m,m,mp=1,rp=2)
print(mean,sd)
# Out:
# 0.03778847455978394 0.00013824512402255397

# %%
ans,mean,sd=timeit(mapreduce_matrixmult,m,m,mp=2,rp=2)
print(mean,sd)
# Out:
# 0.04131392002105713 0.0001857586071032738

# %%
big=np.random.rand(32,32)
print(big)
# Out:
# [[0.22903855 0.34596606 0.75622172 ... 0.83020132 0.77643067 0.60894094]
#  [0.46123371 0.38585371 0.09273281 ... 0.64226986 0.59715403 0.37192755]
#  [0.86670735 0.81820758 0.08647737 ... 0.04689848 0.9085142  0.22603577]
#  ...
#  [0.09627361 0.5255098  0.67160285 ... 0.03533762 0.72662724 0.45179589]
#  [0.35019386 0.38877569 0.30133888 ... 0.25772366 0.88522437 0.62101558]
#  [0.76386968 0.52234017 0.13222605 ... 0.22483833 0.5157115  0.63151478]]

# %%
ans,mean,sd=timeit(mapreduce_matrixmult,big,big,mp=1,rp=1)
print(mean,sd)
# Out:
# 0.6257751202583313 0.011350108948889232

# %%
ans,mean,sd=timeit(mapreduce_matrixmult,big,big,mp=2,rp=2)
print(mean,sd)
# Out:
# 0.49178553581237794 0.008141246160734025
